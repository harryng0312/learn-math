# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### 1. Read data

# %%
import os
# DIR_PATH = "/".join((os.getcwd(), "C3_W1"))
DIR_PATH = os.getcwd()
DIR_PATH
# Out:
# '/Users/hiepnq/Working/training/python/learn-math/C3_W1'

# %%
df_email = pd.read_csv(DIR_PATH + '/emails.csv')
df_email.head(10)
# Out:
#                                                 text  spam
# 0  Subject: naturally irresistible your corporate...     1
# 1  Subject: the stock trading gunslinger  fanny i...     1
# 2  Subject: unbelievable new homes made easy  im ...     1
# 3  Subject: 4 color printing special  request add...     1
# 4  Subject: do not have money , get software cds ...     1
# 5  Subject: great nnews  hello , welcome to medzo...     1
# 6  Subject: here ' s a hot play in motion  homela...     1
# 7  Subject: save your money buy getting this thin...     1
# 8  Subject: undeliverable : home based business f...     1
# 9  Subject: save your money buy getting this thin...     1

# %%
df_email.shape
# Out:
# (5728, 2)

# %% [markdown]
# #### 2. Preprocess data

# %% [markdown]
# ##### 2.1. Shuffer rows

# %%
df = df_email.sample(frac= 1.0, random_state=42, ignore_index = False)

# %% [markdown]
# ##### 2.2. Remove `Subject: `

# %%
X = (df["text"].apply(lambda x: x[9:])
     .to_numpy(dtype=str)) # change data type to ndarray.str
Y = df["spam"].to_numpy(dtype=np.uint8)

# %%
isinstance(X, str)
X
# Out:
# array(['re : energy derivatives conference - may 29 , toronto  good morning amy :  vince kaminski will need the following :  an lcd projector to hook up to a lap tap for his presentation  he will have dinner with the conference organizers and speakers on the 29 th .  he will need 2 nights ( the 28 th and the 29 th ) hotel reservations .  he will send you an abstract shortly .  thanks and have a great day !  shirley crenshaw  713 - 853 - 5290  amy aldous on 03 / 31 / 2000 10 : 50 : 11 am  to : shirley . crenshaw @ enron . com  cc :  subject : re : energy derivatives conference - may 29 , toronto  ms . crenshaw ,  thank you for sending the bio so quickly . it \' s exactly what i was looking  for .  we are planning to compile the conference speakers \' papers for distribution  to the participants . while i will not need dr . kaminski \' s contribution for  several weeks , an abstract of his presentation as soon as possible would be  very useful to the conference organizers .  i will also need the following information :  - dr . kaminski \' s audio / video equipment requirements for his presentation  - will he be joining the conference organizers and speakers for dinner on  may 29 ?  - which nights will he be staying in toronto ? i will reserve a room at the  conference hotel  - any dietary restrictions or special requests  your help is much appreciated .  best wishes ,  amy  at 11 : 50 am 3 / 30 / 00 - 0600 , you wrote :  >  > amy :  >  > attached please find a short " bio " for dr . kaminski . please let me know  > if i can help further .  >  >  > ( see attached file : vincent kaminski bio . doc )  * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *  amy aldous , conference co - ordinator  centre for advanced studies in finance  university of waterloo  waterloo , on n 2 l 3 gl  tel : ( 519 ) 888 - 4567 ext . 5728  fax : ( 519 ) 888 - 7562  email : aaldous @ uwaterloo . ca  * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *',
#        'financial maths course , part 2  vince ,  just in case , here is a draft copy of the event for you to refer to .  paul  - finmathmail . doc',
#        're : bullet points  please respond to hi vince ,  thanks for the bullets . regarding power 2001 , it certainly does promise to  be a very interesting event .  have a great week ,  paul  - - - - - original message - - - - -  from : vince . j . kaminski @ enron . com [ mailto : vince . j . kaminski @ enron . com ]  sent : monday , april 09 , 2001 9 : 11 am  to : pbristow @ riskwaters . com  cc : vince . j . kaminski @ enron . com ; vkaminski @ aol . com  subject : bullet points  paul ,  i am sending you modified bullet points . the modifications are in red .  apologies for a delay in responding to your messages .  by the way , power 2001 gets only more and more interesting every day .  vince  ( see attached file : financial maths draft . doc )',
#        ...,
#        're : my first draft  quentin ,  i forwarded your resume to our sydney office with a request  to invite you for an introductory interview . i would also like to  arrange a phone interview with you sometimes next week .  my assistant will call you regarding the timing .  vince',
#        "why johan dahl and the mri energy staffing group ?  vince ,  it was a pleasure talking with you earlier today . please read the documents i  have attached with this email . let ' s talk in the near future to continue our  conversation . i am very confident that my team and i can be successful  regarding any staffing need you have . ? i will give sheila in hr a call and  see if we can work out a contract . please visit our web site for up - to - date  information at http : / / www . mrportland . com  thank you for your time and have a nice day .  sincerely ,  johan dahl  director energy staffing group  phone : 1 - 503 - 287 - 8701 ext . 1153  email : jdahl @ mrportland . com  - jcd - client broch - energy # 2 . doc  - charter of ethical practice . doc",
#        "perfect visual solution for your business now  working on your company ' s image ? start with a  visual identity a key to the first good impression . we are here to  help you ! we ' ll take part in buiiding a positive visual imaqe  of your company by creatinq an outstandinq logo , presentabie stationery  items and professional website . these marketinq tools wiii siqnificantly  contributeto success of your business . take a look at our work samples , hot deal packages and  see what we have to offer . we work for you !  _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ not interested . . . _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _"],
#       dtype='<U43943')

# %% [markdown]
# #### 2.3. create stop words:

# %%
import string
import nltk
from nltk.corpus import stopwords
from nltk import word_tokenize

nltk.download("stopwords")
nltk.download("punkt")
nltk.download("punkt_tab")
# nltk.download("stopwords", download_dir=DIR_PATH)
# print(nltk.data.path)
# nltk.data.path.append(DIR_PATH)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/hiepnq/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/hiepnq/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/hiepnq/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
stop_words = set(stopwords.words('english')+ list(string.punctuation))
stop_words
# Out:
# {'!',
#  '"',
#  '#',
#  '$',
#  '%',
#  '&',
#  "'",
#  '(',
#  ')',
#  '*',
#  '+',
#  ',',
#  '-',
#  '.',
#  '/',
#  ':',
#  ';',
#  '<',
#  '=',
#  '>',
#  '?',
#  '@',
#  '[',
#  '\\',
#  ']',
#  '^',
#  '_',
#  '`',
#  'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  '{',
#  '|',
#  '}',
#  '~'}

# %% [markdown]
# #### 2.4. Split words

# %%
def split_words(X: np.ndarray|str):
    X_preprocessed = []
    # if X is an email
    if isinstance(X, str):
        X = np.array([X])
        pass
    for i, val in enumerate(X):
        email = np.array([word.lower() for word in word_tokenize(val) if word.lower() not in stop_words]).astype(dtype=str)
        X_preprocessed.append(email)
        pass
    if len(X) == 1:
        return X_preprocessed[0]
    return X_preprocessed

X_treated = split_words(X=X)

# %%
X_treated[:5]
# Out:
# [array(['energy', 'derivatives', 'conference', 'may', '29', 'toronto',
#         'good', 'morning', 'amy', 'vince', 'kaminski', 'need', 'following',
#         'lcd', 'projector', 'hook', 'lap', 'tap', 'presentation', 'dinner',
#         'conference', 'organizers', 'speakers', '29', 'th', 'need', '2',
#         'nights', '28', 'th', '29', 'th', 'hotel', 'reservations', 'send',
#         'abstract', 'shortly', 'thanks', 'great', 'day', 'shirley',
#         'crenshaw', '713', '853', '5290', 'amy', 'aldous', '03', '31',
#         '2000', '10', '50', '11', 'shirley', 'crenshaw', 'enron', 'com',
#         'cc', 'subject', 'energy', 'derivatives', 'conference', 'may',
#         '29', 'toronto', 'ms', 'crenshaw', 'thank', 'sending', 'bio',
#         'quickly', 'exactly', 'looking', 'planning', 'compile',
#         'conference', 'speakers', 'papers', 'distribution', 'participants',
#         'need', 'dr', 'kaminski', 'contribution', 'several', 'weeks',
#         'abstract', 'presentation', 'soon', 'possible', 'would', 'useful',
#         'conference', 'organizers', 'also', 'need', 'following',
#         'information', 'dr', 'kaminski', 'audio', 'video', 'equipment',
#         'requirements', 'presentation', 'joining', 'conference',
#         'organizers', 'speakers', 'dinner', 'may', '29', 'nights',
#         'staying', 'toronto', 'reserve', 'room', 'conference', 'hotel',
#         'dietary', 'restrictions', 'special', 'requests', 'help', 'much',
#         'appreciated', 'best', 'wishes', 'amy', '11', '50', '3', '30',
#         '00', '0600', 'wrote', 'amy', 'attached', 'please', 'find',
#         'short', '``', 'bio', '``', 'dr', 'kaminski', 'please', 'let',
#         'know', 'help', 'see', 'attached', 'file', 'vincent', 'kaminski',
#         'bio', 'doc', 'amy', 'aldous', 'conference', 'co', 'ordinator',
#         'centre', 'advanced', 'studies', 'finance', 'university',
#         'waterloo', 'waterloo', 'n', '2', 'l', '3', 'gl', 'tel', '519',
#         '888', '4567', 'ext', '5728', 'fax', '519', '888', '7562', 'email',
#         'aaldous', 'uwaterloo', 'ca'], dtype='<U12'),
#  array(['financial', 'maths', 'course', 'part', '2', 'vince', 'case',
#         'draft', 'copy', 'event', 'refer', 'paul', 'finmathmail', 'doc'],
#        dtype='<U11'),
#  array(['bullet', 'points', 'please', 'respond', 'hi', 'vince', 'thanks',
#         'bullets', 'regarding', 'power', '2001', 'certainly', 'promise',
#         'interesting', 'event', 'great', 'week', 'paul', 'original',
#         'message', 'vince', 'j', 'kaminski', 'enron', 'com', 'mailto',
#         'vince', 'j', 'kaminski', 'enron', 'com', 'sent', 'monday',
#         'april', '09', '2001', '9', '11', 'pbristow', 'riskwaters', 'com',
#         'cc', 'vince', 'j', 'kaminski', 'enron', 'com', 'vkaminski', 'aol',
#         'com', 'subject', 'bullet', 'points', 'paul', 'sending',
#         'modified', 'bullet', 'points', 'modifications', 'red',
#         'apologies', 'delay', 'responding', 'messages', 'way', 'power',
#         '2001', 'gets', 'interesting', 'every', 'day', 'vince', 'see',
#         'attached', 'file', 'financial', 'maths', 'draft', 'doc'],
#        dtype='<U13'),
#  array(['enron', 'default', 'swaps', 'darrell', 'sending', '2',
#         'technical', 'notes', 'enron', 'default', 'swaps', 'hope',
#         'useful', 'shall', 'read', 'articles', 'weekend', 'curious',
#         'find', 'explanations', 'satisfactory', 'slow', 'preparing',
#         'number', 'technical', 'documents', 'model', 'reviews', 'still',
#         'hope', 'able', 'find', 'time', 'review', 'credit', 'models',
#         'london', 'credit', 'trading', 'var', 'option', 'pricing',
#         'related', 'models', 'also', 'please', 'check', 'invoices',
#         'still', 'think', 'owe', 'money', 'vince', 'darrell', 'duffie',
#         '03', '28', '2001', '08', '07', '38', 'vince', 'j', 'kaminski',
#         'cc', 'subject', 'enron', 'default', 'swaps', 'vince', 'according',
#         'bank', 'america', 'publication', 'enron', 'default', 'swap',
#         'spreads', 'consistently', 'trading', '80', 'basis', 'points',
#         'wider', 'asset', 'swaps', 'idea', 'going', 'thanks', 'guidance',
#         'darrell', 'darrell', 'duffie', 'mail', 'gsb', 'stanford', 'ca',
#         '94305', '5015', 'usa', 'phone', '650', '723', '1976', 'fax',
#         '650', '725', '7979', 'email', 'duffie', 'stanford', 'edu', 'web',
#         'http', 'www', 'stanford', 'edu', 'duffie'], dtype='<U12'),
#  array(['power', 'question', 'steve', 'elena', 'chilkina', 'give',
#         'historical', 'data', 'historical', 'fwd', 'curves', 'obtained',
#         'paulo', 'alex', 'among', 'others', 'course', 'internal',
#         'forward', 'curves', 'represent', 'sensitive', 'information',
#         'vince', 'steven', 'leppard', '10', '13', '2000', '10', '34',
#         'vince', 'j', 'kaminski', 'hou', 'ect', 'ect', 'cc', 'didier',
#         'magne', 'lon', 'ect', 'ect', 'subject', 'power', 'question', 'hi',
#         'vince', 'contact', 'power', 'queries', 'grant', 'gone',
#         'colleague', 'london', 'didier', 'magne', 'giving', 'talk',
#         'power', 'gas', 'arbitrage', 'consequent', 'convergence',
#         'markets', 'presentations', 'area', 'illustrative', 'figures',
#         'increase', 'power', 'gas', 'correlation', 'many', 'thanks',
#         'steve'], dtype='<U13')]

# %% [markdown]
# #### 2.5. Split data

# %%
TRAIN_SIZE = int(0.80*len(X_treated))
X_train = X_treated[:TRAIN_SIZE]
Y_train = Y[:TRAIN_SIZE]
X_test = X_treated[TRAIN_SIZE:]
Y_test = Y[TRAIN_SIZE:]

# %% [markdown]
# ### 3. Calculate Naive Bayes

# %% [markdown]
# #### 3.1. Calculate P(spam) and P(ham):
# $\begin{align}
# P(\text{spam}) &= \frac{\text{\# spam emails}}{\text{\# total emails}}\\
# P(\text{ham}) &= \frac{\text{\# ham emails}}{\text{\# total emails}}\\
# \end{align}$

# %%
class_frequency = {"ham":sum(Y_train==0), "spam": sum(Y_train==1)}
total_email = len(Y_train)
class_frequency
# Out:
# {'ham': 3468, 'spam': 1114}

# %%
prob_spam = class_frequency["spam"]/total_email
prob_ham = class_frequency["ham"]/total_email
prob_ham
# Out:
# 0.7568747271933653

# %% [markdown]
# #### 3.2. Calculate P(email|spam) and P(email|ham):
# $\begin{align}
# P(\text{word}_i\mid\text{spam}) &= \frac{\# \text{email contains word}_i}{\# \text{spam email}}\\
# P(\text{word}_i\mid\text{ham}) &= \frac{\# \text{email contains word}_i}{\# \text{ham email}}\\
# \end{align}$

# %%
def count_word_in_emails(X, Y):
    word_count_dict = {}
    for i, val in enumerate(X_train):
        words_in_email = set(val)
        # print(f"words in email: {set(val)}")
        cls = Y_train[i]
        for word in words_in_email:
            if word not in word_count_dict:
                word_count_dict[word] = {"spam":1,"ham":1}
                pass
            if cls == 0:
                word_count_dict[word]["ham"] += 1
            if cls == 1:
                word_count_dict[word]["spam"] += 1
        pass
    return word_count_dict

# %%
word_frequency = count_word_in_emails(X_treated, Y_train)
word_frequency["lottery"]
# Out:
# {'spam': 9, 'ham': 1}

# %%
test_output = count_word_in_emails([['like','going','river'], ['love', 'deep', 'river'], ['hate','river']], [1,0,0])
print(test_output)
# Out:
# {'conference': {'spam': 5, 'ham': 383}, '853': {'spam': 2, 'ham': 303}, 'know': {'spam': 152, 'ham': 1230}, 'reserve': {'spam': 11, 'ham': 67}, 'see': {'spam': 214, 'ham': 651}, 'lap': {'spam': 3, 'ham': 6}, 'may': {'spam': 201, 'ham': 847}, 'advanced': {'spam': 21, 'ham': 45}, 'joining': {'spam': 2, 'ham': 67}, 'day': {'spam': 133, 'ham': 467}, '``': {'spam': 224, 'ham': 1140}, 'wrote': {'spam': 1, 'ham': 178}, 'finance': {'spam': 11, 'ham': 340}, 'compile': {'spam': 1, 'ham': 9}, 'bio': {'spam': 2, 'ham': 24}, 'morning': {'spam': 30, 'ham': 356}, 'hotel': {'spam': 8, 'ham': 117}, 'uwaterloo': {'spam': 1, 'ham': 9}, 'sending': {'spam': 33, 'ham': 162}, 'cc': {'spam': 5, 'ham': 1719}, 'need': {'spam': 182, 'ham': 774}, 'possible': {'spam': 51, 'ham': 324}, 'wishes': {'spam': 4, 'ham': 53}, 'best': {'spam': 254, 'ham': 570}, 'energy': {'spam': 22, 'ham': 571}, 'appreciated': {'spam': 3, 'ham': 82}, 'staying': {'spam': 2, 'ham': 29}, 'organizers': {'spam': 1, 'ham': 5}, 'special': {'spam': 93, 'ham': 118}, 'com': {'spam': 381, 'ham': 1195}, '7562': {'spam': 1, 'ham': 16}, 'file': {'spam': 25, 'ham': 215}, 'co': {'spam': 33, 'ham': 206}, '888': {'spam': 11, 'ham': 31}, 'exactly': {'spam': 26, 'ham': 39}, 'ms': {'spam': 10, 'ham': 105}, 'doc': {'spam': 3, 'ham': 367}, 'projector': {'spam': 2, 'ham': 14}, 'university': {'spam': 6, 'ham': 465}, 'enron': {'spam': 1, 'ham': 2066}, '00': {'spam': 86, 'ham': 616}, 'speakers': {'spam': 2, 'ham': 66}, 'reservations': {'spam': 3, 'ham': 44}, '03': {'spam': 19, 'ham': 552}, 'video': {'spam': 21, 'ham': 44}, 'fax': {'spam': 34, 'ham': 515}, '519': {'spam': 1, 'ham': 7}, 'short': {'spam': 38, 'ham': 181}, 'gl': {'spam': 5, 'ham': 7}, '2000': {'spam': 23, 'ham': 1377}, 'planning': {'spam': 15, 'ham': 115}, 'following': {'spam': 107, 'ham': 530}, 'weeks': {'spam': 38, 'ham': 221}, 'distribution': {'spam': 21, 'ham': 94}, 'toronto': {'spam': 2, 'ham': 11}, 'waterloo': {'spam': 1, 'ham': 11}, 'email': {'spam': 254, 'ham': 610}, 'vince': {'spam': 2, 'ham': 2223}, 'several': {'spam': 45, 'ham': 222}, 'useful': {'spam': 8, 'ham': 101}, '50': {'spam': 118, 'ham': 171}, 'th': {'spam': 45, 'ham': 522}, 'help': {'spam': 129, 'ham': 557}, 'abstract': {'spam': 2, 'ham': 23}, 'tel': {'spam': 16, 'ham': 170}, 'also': {'spam': 129, 'ham': 894}, '30': {'spam': 90, 'ham': 590}, 'amy': {'spam': 1, 'ham': 38}, 'much': {'spam': 100, 'ham': 443}, 'presentation': {'spam': 14, 'ham': 305}, 'papers': {'spam': 4, 'ham': 59}, 'soon': {'spam': 45, 'ham': 292}, 'tap': {'spam': 2, 'ham': 10}, '3': {'spam': 246, 'ham': 839}, 'aaldous': {'spam': 1, 'ham': 5}, 'participants': {'spam': 9, 'ham': 94}, 'ca': {'spam': 31, 'ham': 120}, '4567': {'spam': 1, 'ham': 5}, '713': {'spam': 1, 'ham': 507}, 'thanks': {'spam': 47, 'ham': 1429}, '11': {'spam': 52, 'ham': 753}, 'shortly': {'spam': 9, 'ham': 40}, '5728': {'spam': 1, 'ham': 5}, 'great': {'spam': 113, 'ham': 358}, 'please': {'spam': 291, 'ham': 1949}, 'quickly': {'spam': 30, 'ham': 68}, 'centre': {'spam': 1, 'ham': 24}, 'dr': {'spam': 12, 'ham': 198}, 'send': {'spam': 131, 'ham': 496}, 'aldous': {'spam': 1, 'ham': 5}, '29': {'spam': 45, 'ham': 285}, 'dinner': {'spam': 1, 'ham': 162}, '31': {'spam': 24, 'ham': 255}, 'room': {'spam': 8, 'ham': 188}, 'equipment': {'spam': 23, 'ham': 44}, 'hook': {'spam': 1, 'ham': 9}, 'thank': {'spam': 69, 'ham': 669}, 'studies': {'spam': 8, 'ham': 50}, 'ext': {'spam': 8, 'ham': 79}, '5290': {'spam': 1, 'ham': 146}, 'ordinator': {'spam': 1, 'ham': 12}, 'crenshaw': {'spam': 1, 'ham': 429}, 'vincent': {'spam': 2, 'ham': 122}, 'kaminski': {'spam': 1, 'ham': 1564}, 'requests': {'spam': 14, 'ham': 58}, 'attached': {'spam': 10, 'ham': 574}, 'nights': {'spam': 3, 'ham': 13}, 'derivatives': {'spam': 1, 'ham': 210}, '28': {'spam': 14, 'ham': 298}, 'subject': {'spam': 148, 'ham': 1805}, 'requirements': {'spam': 21, 'ham': 91}, 'looking': {'spam': 87, 'ham': 295}, '10': {'spam': 181, 'ham': 953}, 'find': {'spam': 105, 'ham': 403}, '2': {'spam': 209, 'ham': 91 ...

# %%
def prob_word_given_class(word, cls):
    qty_word_in_class = word_frequency[word][cls]
    return qty_word_in_class/class_frequency[cls]

# %%
print(f"P(lottery | spam) = {prob_word_given_class('lottery', cls = 'spam')}")
print(f"P(lottery | ham) = {prob_word_given_class('lottery', cls='ham')}")

print(f"P(schedule | spam) = {prob_word_given_class('schedule', cls = 'spam')}")
print(f"P(schedule | ham) = {prob_word_given_class('schedule', cls='ham')}")
# Out:
# P(lottery | spam) = 0.00807899461400359
# P(lottery | ham) = 0.0002883506343713956
# P(schedule | spam) = 0.008976660682226212
# P(schedule | ham) = 0.10294117647058823

# %% [markdown]
# $\begin{align}
# P(\text{email}\mid\text{spam}) &= \prod_{i=1}^n P(\text{word}_i\mid\text{spam}) \\
# P(\text{email}\mid\text{ham}) &= \prod_{i=1}^n P(\text{word}_i\mid\text{ham}) \\
# \end{align}$

# %%
def prob_email_given_class(email, cls):
    """
    Calculate the probability of a given email
    :param email: A list of treated words in the email 
    :param cls: The class of the email
    :return: The probability of the email belonging to the specified class
    """
    prob = 1
    for word in email:
        if word in word_frequency.keys():
            prob *= prob_word_given_class(word, cls)
            pass
        pass
    return prob

# %%
example_email = "Click here to win a lottery ticket and claim your prize!"
treated_email = split_words(example_email)
prob_spam = prob_email_given_class(treated_email, cls = 'spam')
prob_ham = prob_email_given_class(treated_email, cls = 'ham')
print(f"Email: {example_email}\nEmail after preprocessing: {treated_email}\nP(email | spam) = {prob_spam}\nP(email | ham) = {prob_ham}")
# Out:
# Email: Click here to win a lottery ticket and claim your prize!
# Email after preprocessing: ['click' 'win' 'lottery' 'ticket' 'claim' 'prize']
# P(email | spam) = 5.3884806600117164e-11
# P(email | ham) = 1.2428344868918976e-15

# %% [markdown]
# #### 3.3. Calculate all:
# $\begin{align}
# &P(\text{spam}) \cdot P(\text{email}\mid\text{spam}) \\
# &P(\text{ham}) \cdot P(\text{email}\mid\text{ham}) \\
# \end{align}$

# %%
def naive_bayes(emails):
    # calculate P(spam), P(ham)
    prob_spam = class_frequency["spam"]/len(emails)
    prob_ham = class_frequency["ham"]/len(emails)
    # calculate P(email|spam), P(email|ham)
    prob_email_spam = prob_email_given_class(emails, cls = 'spam')
    prob_email_ham = prob_email_given_class(emails, cls = 'ham')
    # calculate spam_likelihood, ham_likelihood
    spam_likelihood = prob_spam * prob_email_spam
    ham_likelihood = prob_spam * prob_email_ham
    
    if spam_likelihood >= ham_likelihood:
        return 1
    return 0

# %%
example_email = "Click here to win a lottery ticket and claim your prize!"
treated_email = split_words(example_email)

print(f"Email: {example_email}\nEmail after preprocessing: {treated_email}\nNaive Bayes predicts this email as: {naive_bayes(treated_email)}")

print("\n\n")
example_email = "Our meeting will happen in the main office. Please be there in time."
treated_email = split_words(example_email)

print(f"Email: {example_email}\nEmail after preprocessing: {treated_email}\nNaive Bayes predicts this email as: {naive_bayes(treated_email)}")
# Out:
# Email: Click here to win a lottery ticket and claim your prize!
# Email after preprocessing: ['click' 'win' 'lottery' 'ticket' 'claim' 'prize']
# Naive Bayes predicts this email as: 1
#
#
#
# Email: Our meeting will happen in the main office. Please be there in time.
# Email after preprocessing: ['meeting' 'happen' 'main' 'office' 'please' 'time']
# Naive Bayes predicts this email as: 0

# %%
def test_naive_bayes():
    pred_true = 0
    for i, email in enumerate(X_test):
        # t_email = split_words(email)
        # print(f"t_email: {email}")
        y_pred = naive_bayes(email)
        y_test = Y_test[i]
        pred_true += (y_pred == y_test)
        pass
    print(f"Pred true:{pred_true}/{len(X_test)}")
    return
test_naive_bayes()
# Out:
# Pred true:972/1146

# %%
972/1146
# Out:
# 0.8481675392670157
